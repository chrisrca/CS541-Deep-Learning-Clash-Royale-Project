# %%
from huggingface_hub import snapshot_download
repo_id = "chrisrca/clash-royale-tv-replays"
arenas=["arena_24", "arena_23", "arena_22", "arena_21", "arena_21"] 
for arena in arenas:
    with open('HUGGING_KEY.txt', 'r') as f:
        snapshot_download(repo_id=repo_id, allow_patterns=f"{arena}/*0/frames.parquet", repo_type="dataset", token=f.read(), cache_dir="F:/Dataset", dry_run=False, max_workers=16,)
    with open('HUGGING_KEY.txt', 'r') as f:
        snapshot_download(repo_id=repo_id, allow_patterns=f"{arena}/*1/frames.parquet", repo_type="dataset", token=f.read(), cache_dir="F:/Dataset", dry_run=False, max_workers=16,)
    with open('HUGGING_KEY.txt', 'r') as f:
        snapshot_download(repo_id=repo_id, allow_patterns=f"{arena}/*2/frames.parquet", repo_type="dataset", token=f.read(), cache_dir="F:/Dataset", dry_run=False, max_workers=16,)
    with open('HUGGING_KEY.txt', 'r') as f:
        snapshot_download(repo_id=repo_id, allow_patterns=f"{arena}/*3/frames.parquet", repo_type="dataset", token=f.read(), cache_dir="F:/Dataset", dry_run=False, max_workers=16,)
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
